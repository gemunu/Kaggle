# %%
pwd
# Out:
# '/Users/gemunu/kaggle/facebook'

# %%
ls
# Out:
# Untitled.ipynb             test.csv                   train.csv.zip
# sample_submission.csv      test.csv.zip
# sample_submission.csv.zip  train.csv

# %%
import pandas as pd

# %%
import seaborn as sns

# %%
# %matplotlib inline
from matplotlib import pyplot as plt

# %%
train=pd.read_csv('train.csv')

# %%
sns.jointplot(train['x'],train['y'])

# %%
len(train)
# Out:
# 29118021

# %%
train.head(2)
# Out:
#    row_id       x       y  accuracy    time    place_id
# 0       0  0.7941  9.0809        54  470702  8523065625
# 1       1  5.9567  4.7968        13  186555  1757726713

# %%
len(train['place_id'].unique())
# Out:
# 108390

# %%
sns.distplot(train['time'])

# %%
sns.jointplot(train['time'],train['accuracy'],size=12,)
